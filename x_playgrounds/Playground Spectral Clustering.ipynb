# %%
from spectralcluster import SpectralClusterer
from sklearn.cluster import SpectralClustering
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from numpy import random


clusterer = SpectralClusterer(
    min_clusters=2,
    max_clusters=100)


X = random.randint(1,10,(3,4))
labels = clusterer.predict(X)
print(labels)

random.seed(1)
x, _ = make_blobs(n_samples=400, centers=4, cluster_std=1.5)
plt.scatter(x[:,0], x[:,1])
plt.show()
# Out:
# [0 0 1]
# C:\Users\artem\anaconda3\envs\tutorials\lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
